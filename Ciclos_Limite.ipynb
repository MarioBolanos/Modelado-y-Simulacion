# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioBolanos/Modelado2020_2/blob/master/Ciclos_Limite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sistema Lodka Volterra
#
# Presa-Depredador

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
def LodkaVolterra (t,xy,A,B,C,D):
  x,y=xy
  return [A*x-B*x*y, -C*y+D*x*y]


a,b,c,d= 1.5, 1,3,1


t_in=0
t_fin=50
xy0=[30, 35]
tspam=[t_in,t_fin]
t=np.linspace(t_in,t_fin,1000)
sol=solve_ivp(LodkaVolterra,tspam,xy0,args=(a,b,c,d),t_eval=t)
plt.plot(sol.t, sol.y[0],label='prey')
plt.plot(sol.t, sol.y[1],label='predators')
#plt.axis([t_in,t_fin,0,15])
plt.legend()

#plt.axis([ti, tf, -10, 10])
plt.grid()

# %%
plt.plot(sol.y[0], sol.y[1],label='prey')
plt.grid()
plt.ylabel('prey')
plt.xlabel('predator')
# Out:
# Text(0.5, 0, 'predator')

# %% [markdown]
# # Lorenz equation

# %%
def Lorenz (t,xyz,sigma,rho,beta):
  x,y,z=xyz
  return [sigma*(y-x), x*(rho-z)-y, x*y-beta*z]


sigma,rho,beta= 10,28,8/3


t_in=0
t_fin=100
xy0=[10, 10, 10]
tspam=[t_in,t_fin]
t=np.linspace(t_in,t_fin,10000)
sol=solve_ivp(Lorenz,tspam,xy0,args=(sigma,rho,beta),t_eval=t)
plt.plot(sol.t, sol.y[0],label='x')
plt.plot(sol.t, sol.y[1],label='y')
#plt.axis([t_in,t_fin,0,15])
plt.legend()

#plt.axis([ti, tf, -10, 10])
plt.grid()

# %%
#plt.plot(sol.y[0], sol.y[1],label='prey')
# plt.grid()
# plt.ylabel('prey')
# plt.xlabel('predator')

ax = plt.axes(projection='3d')
ax.plot3D(sol.y[0], sol.y[1], sol.y[2])
#ax.scatter3D(,"o",color="black")
plt.show()
